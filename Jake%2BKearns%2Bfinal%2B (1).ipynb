# %%
import pandas as pd


#bring in data
mydata = pd.read_excel("soc16.xls")
variables = pd.read_excel("socmicro_variables.xls")

# %%
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
from scipy import stats
from scipy.stats import norm

#Plot the distribution for Price
sns.distplot(mydata["SLPR"])

# %%
sns.distplot(mydata["SQFS"])

# %%
mydata.groupby('DIV')

# %%
#Plot the Regression for Taxes vs Prices
sns.regplot(x=mydata["SLPR"], y=mydata["SQFS"])

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

X = mydata["SQFS"]
Y = mydata["SLPR"]

model = sm.OLS(Y,X)
estt = model.fit()
print(estt.summary())
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#                             OLS Regression Results
# ...
# Dep. Variable:                   SLPR   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                 1.779e+04
# Date:                Wed, 02 May 2018   Prob (F-statistic):               0.00
# Time:                        11:34:06   Log-Likelihood:            -3.1282e+05
# No. Observations:               22661   AIC:                         6.256e+05
# Df Residuals:                   22660   BIC:                         6.256e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
estt.conf_int(alpha=0.05, cols=None)
# Out:
#               0          1
# SQFS  71.822791  73.965352

# %%
mydata['SQFS'].describe()
# Out:
# count    22661.000000
# mean      2607.004854
# std       1289.182790
# min          0.000000
# 25%       1814.000000
# 50%       2433.000000
# 75%       3240.000000
# max       8070.000000
# Name: SQFS, dtype: float64
